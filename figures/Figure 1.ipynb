# %% [markdown]
# # Behavioral tasks

# %% [markdown]
# ## Description of the 3 tasks

# %% [markdown]
# This is just a placeholder, as the figures will be cartoons done in Inkscape

# %% [markdown]
# ## Main psychometric curves (no pharma) for each task

# %% [markdown]
# ### Tiffany's

# %% [markdown]
# ### Alexis'

# %% [markdown]
# ### Balma's

# %% [markdown]
# ## Mice in the 3 tasks show repeating lapses (no pharma)

# %% [markdown]
# ### Tiffany's

# %% [markdown]
# ### Alexis'

# %% [markdown]
# ### Balma's
